# %% [markdown]
# these need to be added to kstest, with explicit documentation that describes uses. such as poisson and binomial, and soforth

# %%
### the following still need fit parameters and args befor they can be supported

        if 'exponential' in distributions:
            _ , exponential_p_value = scipy.stats.kstest(data, scipy.stats.expon(loc=self.mean,scale=self.std).cdf) 
            p_values['esponential']=uniform_p_value
        if 'logistic' in distributions:
            _ , logistic_p_value = scipy.stats.kstest(data, scipy.stats.logistic(loc=self.mean,scale=self.std).cdf) 
            p_values['logistic']=uniform_p_value
        """if 'beta' in distributions:
            _ , beta_p_value = scipy.stats.kstest(data, scipy.stats.beta(x, a, b, loc=0, scale=1).cdf) 
            p_values['beta']=uniform_p_value            
            common in binomial ditributions
            Where alpha(a) represents prior successes and beta(b) represients prior failures
            - a=b=1 → Uniform distribution on [0,1]
            - a>1,b>1 → Bell-shaped curve
            - a<1,b<1 → U-shaped curve
            - a>b → Skewed toward 1
            - a<b → Skewed toward 0"""
        """if 'gamma' in distributions:
            _ , uniform_p_value = scipy.stats.kstest(data, scipy.stats.gamma(x, a, loc=0, scale=1).cdf) 
            p_values['gamma']=uniform_p_value
            where alpha(a) is number of events
            - a=1 → Exponential distribution
            - a<1 → Right-skewed, heavy tail
            - a>1 → More symmetric, bell-shaped as a increases
            & scale is not std """
        """if 'weibull_min' in distributions:
            _ , weibull_min_p_value = scipy.stats.kstest(data, scipy.stats.weibull_min(..........).cdf) 
            p_values['weibull_min']=uniform_p_value"""
        """if 'lognorm' in distributions:
            _ , uniform_p_value = scipy.stats.kstest(data, scipy.stats.lognorm(........).cdf) 
            p_values['lognorm']=uniform_p_value"""
        """if 'chi2' in distributions:
            _ , uniform_p_value = scipy.stats.kstest(data, scipy.stats.chi2(..............).cdf) 
            p_values['chi2']=uniform_p_value"""
        """if 'pareto2' in distributions:
            _ , uniform_p_value = scipy.stats.kstest(data, scipy.stats.pareto2(..............).cdf) 
            p_values['pareto']=uniform_p_value
        return p_values"""

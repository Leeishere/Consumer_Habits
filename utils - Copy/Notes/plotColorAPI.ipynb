# %%
#git: https://github.com/y-sunflower/pypalettes
#docs: https://python-graph-gallery.com/introduction-to-pypalettes/

# %%
#quickstart:

import geopandas as gpd
import matplotlib.pyplot as plt
from pypalettes import load_cmap, load_palette

# load the dataset
df = gpd.read_file(
    "https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/all_world.geojson"
)
df = df[df["name"] != "Antarctica"]

cmap = load_cmap("Coconut")

# display the world map
fig, ax = plt.subplots(figsize=(10, 10), dpi=300)
ax.set_axis_off()
df.plot(ax=ax, cmap=cmap, edgecolor="white", linewidth=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 #quickstart:
# ----> 3 import geopandas as gpd
#       4 import matplotlib.pyplot as plt
#       5 from pypalettes import load_cmap, load_palette
#
# ModuleNotFoundError: No module named 'geopandas'
